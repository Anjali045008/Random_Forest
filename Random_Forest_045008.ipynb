# %% [markdown]
# ##**Random Forest**
#
# **Classification of Vehicle Data into {Segments | Clusters | Classes} using Cross-Validation and Ensemble Methods**
#
# **1. Project Objectives | Problem Statements**
#
#   1.1. PO1 | PS1: Classification of Vehicle Data into {Segments | Clusters | Classes} using Cross-Validation
#
#   1.2. PO2 | PS2: Classification of Vehicle Data into {Segments | Clusters | Classes} using Ensemble Methods
#
#   1.3. PO3 | PS3: Determination of an Appropriate Classification Model (Default vs Cross-Validation or Ensemble)
#
#   1.4. PO4 | PS4: Identification of Important | Contributing | Significant Variables or Features and their Thresholds for Classification'''
#
#
# **2. Description of Data**
#
# 2.1. Data Source, Size, Shape
#
# 2.1.1. Data Source (https://www.kaggle.com/datasets/syedanwarafridi/vehicle-sales-data/data)
#
# 2.1.2. Data Size (8.9 MB)
#
# 2.1.3. Data Shape (Dimension: Number of Variables-14 | Number of Records-100001 rows × 14 columns)
#
# **2.2. Description of Variables**
#
# **2.2.1. Index Variable(s)**
#
# Index Variable(s): Index Column Number
#
# **.2.2. Variables or Features having Categories | Categorical Variables or Features (CV)**
#
# **2.2.2.1. Variables or Features having Nominal Categories | Categorical
# Variables or Features - Nominal Type**
#
# **Nominal Categories:**
#
# 1.Year
# 2.Body Type
# 3.Color
# 5.Interior
# 6.Seller
# 7 .cluster
#
# **2.2.2.2. Variables or Features having Ordinal Categories | Categorical Variables or Features - Ordinal Type**
#
# **Ordinal Categories:**
#
# None in this dataset
#
# **2.2.3. Non-Categorical Variables or Features
# Non-Categorical Variables or Features:**
#
# 1.Selling Price
# 2. Wholesale Price
# 3. Mileage
# 4. Odometer
# 5. Condition
# 6. Transmission
#
# Variable Descriptions:
#
# Index Variable:
#
# Car Name: Name of the vehicle
#
# Categorical Variables:
#
# Nominal Categories:
#
# Year: Manufacturing year of the vehicle Body Type: Type of vehicle body (e.g., sedan, SUV, hatchback) Color: Color of the vehicle Interior: Interior type of the vehicle (e.g., leather, fabric) Seller: Type of seller (e.g., individual, dealer)
#
# Non-Categorical Variables:
#
# Selling Price: Price at which the vehicle is being sold Wholesale Price: Wholesale price of the vehicle Mileage: Mileage of the vehicle Odometer: Total distance traveled by the vehicle Condition: Condition of the vehicle Transmission: Type of transmission (e.g., manual, automatic)
#
# #**2.3. Descriptive Statistics**
#
# 2.3. Descriptive Statistics
#
# 2.3.1. Descriptive Statistics: Categorical Variables or Features
#
# 2.3.1.1. Count | Frequency Statistics
#
# Count of Unique Values in Categorical Features:
#
#
# Transmission:
#
# Manual: 69333
#
# Automatic: 15007
#
# Seller:
#
# Individual: 100000
#
# Mileage:
# 5: 5
# 4: 5
#
# 2.3.1.2. Proportion (Relative Frequency) Statistics
#
# Proportion of Unique Values in Categorical Features:
#
# Transmission:
#
# Manual: 82.19%
#
# Automatic: 17.81%
#
# Seller:
#
# Individual: 100%
#
# Mileage:
#
# 5: 0.0005%
#
# 4: 0.0005%
#
# 2.3.2. Descriptive Statistics: Non-Categorical Variables or Features
#
# 2.3.2.1. Measures of Central Tendency
#
# Mean:
#
# Year: 2009.293750
#
# Odometer: 75147.522172
#
# Wholesale Price: 12558.999500
#
# Selling Price: 12230.463520
#
# Mileage: 99819.395000
#
# 2.3.2.2. Measures of Dispersion
#
# Standard Deviation:
#
# Year: 4.256992
#
# Odometer: 57711.981006
#
# Wholesale Price: 9321.047724
#
# Selling Price: 9333.910641
#
# Mileage: 57710.087058
#
# 2.3.2.3. Correlation Statistics (with Test of Correlation)
#
# Correlation Matrix:
#
# Year vs. Selling Price: (0.29)
#
# Year vs. Odometer: (0.41)
#
# Selling Price vs. Odometer: (0.19)
#
# Year vs. Mileage: (0.41)
#
# Selling Price vs. Mileage: (-0.19)
#
# Odometer vs. Mileage: (0.19)
#
# **Summary:**
#
# The dataset consists of 12 columns and 100,000 records. Categorical features include 'Transmission', 'Seller', and 'Mileage', while non-categorical features include 'Year', 'Odometer', 'Wholesale Price', 'Selling Price', and 'Mileage'. Descriptive statistics provide insights into the distribution of data, including count, proportion, mean, standard deviation, and correlation coefficients.
#
# ### **3.1. Data Pre-Processing**
#
# **3.1. Data Pre-Processing**
#
# **3.1.1. Missing Data Statistics and Treatment**
#
# Variable-wise Missing Data Information:
#
# There are missing values present in the following variables:
#
# 'name': 425 missing values
# 'body': 2,731 missing values
# 'transmission': 12,000 missing values
# 'odometer': 75 missing values
# 'color': 183 missing values
# 'interior': 7,437 missing values
#
# **3.1.2. Numerical Encoding of Categorical Variables**
#
# Ordinal Encoder: Utilized to convert categorical variables into numerical representations.
#
# **3.1.3. Outlier Statistics and Treatment**
#
# Outlier Detection:Outliers were identified using boxplot visualization.
#
# Outlier Treatment:Outliers were addressed by performing normalization using Min-Max Scaler.
#
# **3.1.4. Data Transformation and Scaling**
#
# Normalization: Min-Max Scaling was applied to non-categorical variables to bring them within a common scale.
#
# **3.1.5. Pre-Processed Dataset Overview**
#
# Pre-Processed Categorical Data Subset:Categorical data was encoded using Ordinal Encoder.
#
# Pre-Processed Non-Categorical Data Subset:Non-categorical data was normalized using Min-Max Scaler.
#
# Pre-Processed Dataset:The pre-processed categorical and non-categorical data subsets were merged.
#
# ---
#
# ## **Data Analysis Report**
#
# ## **3.2. Data Analysis**
#
# **3.2.1.1. PO1 | PS1: Supervised Machine Learning Classification Algorithm: Decision Tree (Base Model) | Metrics Used - Accuracy**
#
# - **Accuracy:** 0.9671
#
# **Analysis:** The Decision Tree base model achieves an accuracy of 0.9671, indicating strong performance in correctly classifying instances in the dataset.
#
# **3.2.1.2. PO1 | PS1: Supervised Machine Learning Classification Algorithms: Random Forest (Comparison Model) | Metrics Used**
#
# For the Random Forest model:
# - **Accuracy (Testing Set):** 1.0
#
# **Analysis:** The Random Forest model exhibits perfect accuracy on the testing set, showcasing its robustness and generalization ability.
#
# **3.2.2.1.1. PO2 | PS2: Classification Model Performance Evaluation: Confusion Matrix {Accuracy} (Base Model: Decision Tree)**
#
# For the Decision Tree model:
# - **Accuracy:** 0.9671
#
# **Analysis:** The Decision Tree base model demonstrates strong accuracy, indicating its effectiveness in predicting outcomes.
#
# **3.2.2.2.1. PO2 | PS2: Classification Model Performance Evaluation: Confusion Matrix {Accuracy} (Comparison Model: Random Forest)**
#
# For the Random Forest model:
# - **Accuracy:** 0.9966
#
# **Analysis:** The Random Forest model achieves perfect accuracy on the testing set, further validating its predictive capability.
#
# **3.2.2.1.2. PO2 | PS2: Classification Model Performance Evaluation: Time Statistics | Memory Statistics (Base Model: Decision Tree)**
#
# For the Decision Tree model:
# - **Training Time (s):** 0.5499
# - **Memory Used (MB):** 481.29
#
# **Analysis:** The Decision Tree model exhibits moderate training time and memory usage, contributing to its efficiency.
#
# **3.2.2.2.2. PO2 | PS2: Classification Model Performance Evaluation: Time Statistics | Memory Statistics (Comparison Model: Random Forest)**
#
# For the Random Forest model:
# - **Training Time (s):** 14.1681
# - **Memory Used (MB):** 482.58
#
# **Analysis:** The Random Forest model requires longer training time compared to the Decision Tree model but maintains similar memory usage, showcasing its scalability.
#
# **3.2.3.1. PO3 | PS3: Variable or Feature Analysis: Base Model (Decision Tree)**
#
# For the Decision Tree model:
# - **Relevant Variables and Thresholds:**
#   - wholesale_price_mmnorm: Threshold 0.955
#
# **Analysis:** The feature "wholesale_price_mmnorm" with a threshold of 0.955 is identified as the most relevant variable, indicating its significant impact on the Decision Tree model's predictions.
#
# **Comparison between Decision Tree and Random Forest:**
#
# - **Accuracy:** Both models exhibit high accuracy, with the Decision Tree model achieving an accuracy of 0.9671 and the Random Forest model achieving perfect accuracy on the testing set.
#
# - **Time and Memory Usage:** The Decision Tree model demonstrates faster training time but slightly higher memory usage compared to the Random Forest model. However, both models exhibit reasonable resource requirements.
#
# - **Feature Importance:** Both models highlight the importance of "wholesale_price_mmnorm," indicating its significant influence on prediction outcomes.
#
# **3.2.3.2. PO3 | PS3: Variable or Feature Analysis: Comparison Model (Random Forest)**
#
# For the Random Forest model:
#
# **Feature Importance:**
# - wholesale_price_mmnorm: 0.4388
# - selling_price_mmnorm: 0.4367
# - odometer_mnorm: 0.086
#
# **Analysis:** The Random Forest model assigns importance to multiple features, with "wholesale_price_mmnorm" and "selling_price_mmnorm" being the most influential, followed by "odometer_mnorm."
#
# ##**4. Results | Observations**
#
# **4.1. Classification Model Parameters**
#
# **Base Model (Decision Tree):**
# - Accuracy: 0.9671
#
# **Comparison Model (Random Forest):**
# - Accuracy: 0.9966
#
# **4.2. Classification Model Performance: Time & Memory Statistics**
#
# **Base Model (Decision Tree):**
# - Training Time (s): 0.5499
# - Memory Used (MB): 481.29
#
# **Comparison Model (Random Forest):**
# - Training Time (s): 14.1681
# - Memory Used (MB): 482.58
#
# **4.3. Variable or Feature Analysis**
#
# **Base Model (Decision Tree)**
# - **List of Relevant or Important Variables or Features and their Thresholds:**
#   - wholesale_price_mmnorm: 0.955
#
# **Comparison Model (Random Forest)**
# - **List of Relevant or Important Variables or Features and their Importance Scores:**
#   - wholesale_price_mmnorm: 0.4388
#   - selling_price_mmnorm: 0.4367
#   - odometer_mnorm: 0.086
#
# ##**5. Managerial Insights**
#
# **5.1. Appropriate Model: Compare and Contrast {Decision Tree | Random Forest}**
#
# **Training Time:** The Decision Tree model continues to demonstrate faster training time compared to the Random Forest model, making it more efficient for training on the given dataset.
#
# **Memory Usage:** Both models exhibit similar memory usage, with the Decision Tree model showing slightly higher usage. However, the difference is negligible.
#
# **Accuracy:** While both models maintain high accuracy, the Random Forest model achieves perfect accuracy on the testing set, showcasing its robustness.
#
# **Managerial Insight:** Despite the longer training time, the Random Forest model's superior accuracy on the testing set suggests its suitability for real-world deployment where high predictive accuracy is paramount. However, the Decision Tree model remains a practical choice for scenarios where computational efficiency is a priority.
#
# **5.2. Relevant or Important Variables or Features (Given the Appropriate Model)**
#
# **Relevant Features:**
# - Both models emphasize the importance of "wholesale_price_mmnorm," highlighting its significant influence on prediction outcomes.
#
# **Managerial Insight:** Managers should focus on understanding the dynamics of "wholesale_price_mmnorm" as it plays a crucial role in predicting classification outcomes. Strategies aimed at optimizing this feature can lead to improved model performance and better decision-making.
#
# ##**Real-Life Managerial Insights:**
#
# 1. **Price Sensitivity Analysis:**
#    - Managers should conduct thorough analyses of wholesale and selling prices to identify pricing strategies that maximize profitability while meeting consumer demand. Insights from feature importance analysis can guide pricing decisions and help anticipate market responses to price changes.
#
# 2. **Customer Segmentation and Targeted Marketing:**
#    - Leveraging the identified influential features, managers can segment customers based on price sensitivity and preferences. Tailored marketing strategies can then be developed to address the unique needs of each segment, enhancing customer engagement and satisfaction.
#
# 3. **Inventory Management Optimization:**
#    - Understanding the impact of wholesale prices on classification outcomes can aid in optimizing inventory levels and distribution strategies. By aligning inventory with predicted demand patterns, managers can minimize stockouts and excess inventory, leading to cost savings and improved operational efficiency.
#
# 4. **Market Positioning and Competitive Analysis:**
#    - Comparative analysis of wholesale and selling prices across competitors can provide valuable insights into market positioning and competitive advantage. Managers can use this information to refine pricing strategies, differentiate themselves from competitors, and capitalize on market opportunities.

# %%
# Required Libraries
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import pandas as pd, numpy as np # For Data Manipulation
import matplotlib.pyplot as plt, seaborn as sns # For Data Visualization
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation

# %%
df=pd.read_csv("proj_2.csv")
df
# Out:
#        Unnamed: 0  year     name   body transmission  odometer  color  \
# 0               0  2015      Kia    SUV    automatic   16639.0  white
# 1               1  2015      Kia    SUV    automatic    9393.0  white
# 2               2  2014      BMW  Sedan    automatic    1331.0   gray
# 3               3  2015    Volvo  Sedan    automatic   14282.0  white
# 4               4  2014      BMW  Sedan    automatic    2641.0   gray
# ...           ...   ...      ...    ...          ...       ...    ...
# 99995       99995  2008  Hyundai    SUV    automatic   91368.0  green
# 99996       99996  2008    Honda    SUV    automatic  121509.0  white
# 99997       99997  2008   HUMMER    SUV    automatic  108000.0  black
# 99998       99998  2008  Hyundai  Sedan          NaN  125126.0  white
# 99999       99999  2008    Honda    SUV    automatic  106383.0   blue
#
#       interior                                   seller  wholesale_price  \
# ...

# %%
df_cat = df[['name','body','transmission','color','interior','seller','Condition']] # Categorical Data [Nominal | Ordinal]
df_noncat = df[['selling_price', 'wholesale_price','Mileage','odometer']] # Non-Categorical Data

# %%
print(df.info()) # Dataframe Information (Provide Information on Missing Data)
print(df.describe())
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
print(variable_missing_data)
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
print(record_missing_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       100000 non-null  int64
#  1   year             100000 non-null  int64
#  2   name             99575 non-null   object
#  3   body             97269 non-null   object
#  4   transmission     88000 non-null   object
#  5   odometer         99925 non-null   float64
#  6   color            99817 non-null   object
#  7   interior         92563 non-null   object
#  8   seller           100000 non-null  object
#  9   wholesale_price  100000 non-null  int64
#  10  selling_price    100000 non-null  int64
#  11  Mileage          100000 non-null  int64
#  12  Condition        100000 non-null  object
#  13  cluster          100000 non-null  int64
# dtypes: float64(1), int64(6), object(7)
# memory usage: 10.7+ MB
# None
# ...

# %%
# 1.2.1. Impute Missing Categorical Data [Nominal | Ordinal] using Descriptive Satatistics : Central Tendency (Mode)


# Dataset Used : df_cat

si_cat = SimpleImputer(missing_values=np.nan, strategy='most_frequent') # Strategy = median [When Odd Number of Categories Exists]
si_cat_fit = si_cat.fit_transform(df_cat)
df_cat_mdi = pd.DataFrame(si_cat_fit, columns=df_cat.columns); df_cat_mdi # Missing Categorical Data Imputed Subset
df_cat_mdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   name          100000 non-null  object
#  1   body          100000 non-null  object
#  2   transmission  100000 non-null  object
#  3   color         100000 non-null  object
#  4   interior      100000 non-null  object
#  5   seller        100000 non-null  object
#  6   Condition     100000 non-null  object
# dtypes: object(7)
# memory usage: 5.3+ MB

# %%
# 1.2.1. Impute Missing Categorical Data [Nominal | Ordinal] using Descriptive Satatistics : Central Tendency (Mode)


# Dataset Used : df_cat

si_cat = SimpleImputer(missing_values=np.nan, strategy='most_frequent') # Strategy = median [When Odd Number of Categories Exists]
si_cat_fit = si_cat.fit_transform(df_cat)
df_cat_mdi = pd.DataFrame(si_cat_fit, columns=df_cat.columns); df_cat_mdi # Missing Categorical Data Imputed Subset
df_cat_mdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   name          100000 non-null  object
#  1   body          100000 non-null  object
#  2   transmission  100000 non-null  object
#  3   color         100000 non-null  object
#  4   interior      100000 non-null  object
#  5   seller        100000 non-null  object
#  6   Condition     100000 non-null  object
# dtypes: object(7)
# memory usage: 5.3+ MB

# %%
# 1.2.2.1. Impute Missing Non-Categorical Data using Descriptive Statistics : Central Tendency
# --------------------------------------------------------------------------------------------

# Dataset Used : df_noncat

si_noncat = SimpleImputer(missing_values=np.nan, strategy='mean') # Other Strategy : mean | median | most_frequent | constant
si_noncat_fit = si_noncat.fit_transform(df_noncat)
df_noncat_mdi_si = pd.DataFrame(si_noncat_fit, columns=df_noncat.columns); df_noncat_mdi_si # Missing Non-Categorical Data Imputed Subset using Simple Imputer
df_noncat_mdi_si.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   selling_price    100000 non-null  float64
#  1   wholesale_price  100000 non-null  float64
#  2   Mileage          100000 non-null  float64
#  3   odometer         100000 non-null  float64
# dtypes: float64(4)
# memory usage: 3.1 MB

# %%
#Numeric Encoding of Categorical Data [Nominal & Ordinal]
df_cat_mdt_code = df_cat_mdi.copy()
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat_mdt_code)
df_cat_code_oe = pd.DataFrame(oe_fit, columns=['name_code','body_code','transmission_code','color_code','interior_code','seller_code','condition_code']); df_cat_code_oe
#df_cat_mdt_code_oe = df_cat_mdt_code.join(df_cat_code_oe); df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
df_cat_mdt_code_oe = pd.merge(df_cat_mdt_code, df_cat_code_oe, left_index=True, right_index=True);
df_cat_mdt_code_oe
# Out:
#           name   body transmission  color interior  \
# 0          Kia    SUV    automatic  white    black
# 1          Kia    SUV    automatic  white    beige
# 2          BMW  Sedan    automatic   gray    black
# 3        Volvo  Sedan    automatic  white    black
# 4          BMW  Sedan    automatic   gray    black
# ...        ...    ...          ...    ...      ...
# 99995  Hyundai    SUV    automatic  green     gray
# 99996    Honda    SUV    automatic  white    brown
# 99997   HUMMER    SUV    automatic  black    black
# 99998  Hyundai  Sedan    automatic  white     gray
# 99999    Honda    SUV    automatic   blue    black
#
#                                         seller Condition  name_code  \
# 0                      kia motors america  inc       New       23.0
# 1                      kia motors america  inc       New       23.0
# 2       financial services remarketing (lease)       New        3.0
# 3                      volvo na rep/world omni      Used       48.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame and contains the columns 'Offers', 'Average Price', and 'Number of Ratings'
df_noncat = df[['selling_price', 'wholesale_price','Mileage','odometer']]

# Create vertical boxplot for 'Offers'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['selling_price'])
plt.title('Boxplot of selling_price')
plt.ylabel('selling_price')
plt.show()

# Create vertical boxplot for 'Average Price'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['wholesale_price'])
plt.title('Boxplot of km_driven')
plt.ylabel('km_driven')
plt.show()

# Create vertical boxplot for 'Offers'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['Mileage'])
plt.title('Boxplot of Mileage')
plt.ylabel('selling_price')
plt.show()

# Create vertical boxplot for 'Offers'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['odometer'])
plt.title('Boxplot of odometer')
plt.ylabel('selling_price')
plt.show()

# %%
# 3.2.1. Normalization : Min-Max Scaling
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_noncat_mdi_si [['selling_price', 'wholesale_price','Mileage','odometer']])
df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=['selling_price_mmnorm', 'wholesale_price_mmnorm','Mileage_mnorm','odometer_mnorm']); df_noncat_minmax_norm

#df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=df_noncat_mdt.columns+'_mmnorm'); df_noncat_minmax_norm
#df_noncat_mdt_mmn = df_noncat_mdi_si.join(df_noncat_minmax_norm); df_noncat_mdt_mmn # (Missing Data Treated) Normalized Non-Categorical Dataset using Sikit Learn Min-Max Scaler
df_noncat_mdt_mmn = pd.merge(df_noncat_mdi_si, df_noncat_minmax_norm, left_index=True, right_index=True); df_noncat_mdt_mmn
# Out:
#        selling_price  wholesale_price   Mileage  odometer  \
# 0            21500.0          20500.0   22932.0   16639.0
# 1            21500.0          20800.0   89937.0    9393.0
# 2            30000.0          31900.0   36616.0    1331.0
# 3            27750.0          27500.0   82812.0   14282.0
# 4            67000.0          66000.0  184616.0    2641.0
# ...              ...              ...       ...       ...
# 99995         3800.0           7725.0   24034.0   91368.0
# 99996         9250.0           6850.0   30029.0  121509.0
# 99997         9900.0          11300.0   42313.0  108000.0
# 99998         3100.0           2475.0  120989.0  125126.0
# 99999         8200.0           9225.0  138318.0  106383.0
#
#        selling_price_mmnorm  wholesale_price_mmnorm  Mileage_mnorm  \
# 0                  0.137815                0.130435       0.114652
# 1                  0.137815                0.132346       0.449684
# ...

# %%
# Pre-Processed Dataset

# Using Scikit Learn Ordinal Encoder : df_cat_mdt_code_oe [Superior]

# Missing Data Treated & Transformed or Rescaled Non-Categorical Data Subsets

# Using Scikit Learn Standard Scaler : df_noncat_mdt_std [Standardization]


# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd # Preferred Data Subset

# Pre-Processed Non-Categorical Data Subset
df_noncat_ppd = df_noncat_mdt_mmn.copy(); df_noncat_ppd


# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_noncat_ppd); df_ppd # Pre-Processed Dataset
df_ppd = pd.merge(df_cat_ppd, df_noncat_ppd, left_index=True, right_index=True); df_ppd
final_df = pd.merge(df_ppd, df[['cluster']], how='left', left_index=True, right_index=True)
final_df = final_df.drop([83944])
print(final_df)
# Out:
#           name   body transmission  color interior  \
# 0          Kia    SUV    automatic  white    black
# 1          Kia    SUV    automatic  white    beige
# 2          BMW  Sedan    automatic   gray    black
# 3        Volvo  Sedan    automatic  white    black
# 4          BMW  Sedan    automatic   gray    black
# ...        ...    ...          ...    ...      ...
# 99995  Hyundai    SUV    automatic  green     gray
# 99996    Honda    SUV    automatic  white    brown
# 99997   HUMMER    SUV    automatic  black    black
# 99998  Hyundai  Sedan    automatic  white     gray
# 99999    Honda    SUV    automatic   blue    black
#
#                                         seller Condition  name_code  \
# 0                      kia motors america  inc       New       23.0
# 1                      kia motors america  inc       New       23.0
# 2       financial services remarketing (lease)       New        3.0
# 3                      volvo na rep/world omni      Used       48.0
# ...

# %%
final_new_df=final_df[['selling_price_mmnorm', 'wholesale_price_mmnorm','Mileage_mnorm','odometer_mnorm','name_code','body_code','transmission_code','color_code','interior_code','seller_code','condition_code']]

# %%
# Import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree  # For Decision Tree Model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, classification_report # For Decision Tree Model Evaluation
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from matplotlib.colors import ListedColormap
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score
from matplotlib.colors import ListedColormap

# %%
cars_inputs = final_df[['selling_price_mmnorm', 'wholesale_price_mmnorm','Mileage_mnorm','odometer_mnorm','name_code','body_code','transmission_code','color_code','interior_code','seller_code','condition_code']]; cars_inputs
cars_output = final_df[['cluster']]; cars_output

cars_inputs_names = cars_inputs.columns; cars_inputs_names
cars_output_labels = cars_output['cluster'].unique().astype(str); cars_output_labels

# Split the mtcars Data Subset into Training & Testing Sets
train_cars_inputs, test_cars_inputs, train_cars_output, test_cars_output = train_test_split(cars_inputs, cars_output, test_size=0.25, random_state=1234)

# %%
# Initialize StratifiedShuffleSplit with desired test size and random state
stratified_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=45011)

# Perform the stratified split to get training and testing indices
for train_index, test_index in stratified_split.split(cars_inputs, cars_output):
    cars_inputs_train, cars_inputs_test = cars_inputs.iloc[train_index], cars_inputs.iloc[test_index]
    cars_output_train, cars_output_test = cars_output.iloc[train_index], cars_output.iloc[test_index]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
import numpy as np

# Initialize Logistic Regression model with L1 regularization
logreg_l1 = LogisticRegression(penalty='l1', solver='liblinear', random_state=45011)

# Fit the model on the training data
logreg_l1.fit(cars_inputs_train, cars_output_train.values.ravel())

# Get feature importances from the fitted model
feature_importances = np.abs(logreg_l1.coef_).flatten()

# Calculate the threshold as 20% of the maximum feature importance
threshold = 0.2 * np.max(feature_importances)

# Create a selector object to select features based on non-zero coefficients
selector = SelectFromModel(logreg_l1, threshold=threshold)

# Transform the training and testing input data to select features
cars_inputs_train_selected = selector.transform(cars_inputs_train)
cars_inputs_test_selected = selector.transform(cars_inputs_test)

# Get the selected features
selected_features = cars_inputs_names[selector.get_support()]

# Print the selected features and the calculated threshold
print("Selected Features:", selected_features)
print("Threshold:", threshold)
# Out:
# Selected Features: Index(['selling_price_mmnorm', 'wholesale_price_mmnorm'], dtype='object')
# Threshold: 57.07425623461991
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
# Initialize StratifiedShuffleSplit with desired test size and random state
stratified_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=45007)

# Perform the stratified split to get training and testing indices
for train_index, test_index in stratified_split.split(cars_inputs, cars_output):
    cars_inputs_train, cars_inputs_test = cars_inputs.iloc[train_index], cars_inputs.iloc[test_index]
    cars_output_train, cars_output_test = cars_output.iloc[train_index], cars_output.iloc[test_index]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
import numpy as np

# Initialize Logistic Regression model with L1 regularization
logreg_l1 = LogisticRegression(penalty='l1', solver='liblinear', random_state=45007)

# Fit the model on the training data
logreg_l1.fit(cars_inputs_train, cars_output_train.values.ravel())

# Get feature importances from the fitted model
feature_importances = np.abs(logreg_l1.coef_).flatten()

# Calculate the threshold as 20% of the maximum feature importance
threshold = 0.2 * np.max(feature_importances)

# Create a selector object to select features based on non-zero coefficients
selector = SelectFromModel(logreg_l1, threshold=threshold)

# Transform the training and testing input data to select features
cars_inputs_train_selected = selector.transform(cars_inputs_train)
cars_inputs_test_selected = selector.transform(cars_inputs_test)

# Get the selected features
selected_features = cars_inputs_names[selector.get_support()]

# Print the selected features and the calculated threshold
print("Selected Features:", selected_features)
print("Threshold:", threshold)
# Out:
# Selected Features: Index(['selling_price_mmnorm', 'wholesale_price_mmnorm', 'odometer_mnorm'], dtype='object')
# Threshold: 41.49614081998826
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
# Decision Tree : Model (Training Subset)
dtc = DecisionTreeClassifier(criterion='gini', random_state=45007,max_depth=3) # Other Criteria : Entropy,  Log Loss
dtc_model = dtc.fit(cars_inputs_train, cars_output_train); dtc_model
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=45007)

# %%
# Decision Tree : Model Rules
dtc_model_rules = export_text(dtc_model, feature_names = list(cars_inputs_names)); print(dtc_model_rules)
# Out:
# |--- wholesale_price_mmnorm <= 0.05
# |   |--- selling_price_mmnorm <= 0.06
# |   |   |--- selling_price_mmnorm <= 0.06
# |   |   |   |--- class: 0
# |   |   |--- selling_price_mmnorm >  0.06
# |   |   |   |--- class: 0
# |   |--- selling_price_mmnorm >  0.06
# |   |   |--- wholesale_price_mmnorm <= 0.05
# |   |   |   |--- class: 0
# |   |   |--- wholesale_price_mmnorm >  0.05
# |   |   |   |--- class: 1
# |--- wholesale_price_mmnorm >  0.05
# |   |--- wholesale_price_mmnorm <= 0.11
# |   |   |--- selling_price_mmnorm <= 0.05
# |   |   |   |--- class: 0
# |   |   |--- selling_price_mmnorm >  0.05
# |   |   |   |--- class: 1
# |   |--- wholesale_price_mmnorm >  0.11
# |   |   |--- wholesale_price_mmnorm <= 0.20
# |   |   |   |--- class: 3
# |   |   |--- wholesale_price_mmnorm >  0.20
# |   |   |   |--- class: 2

# %%
# Decision Tree : Feature Importance
dtc_imp_features = pd.DataFrame({'feature': cars_inputs_names, 'importance': np.round(dtc_model.feature_importances_, 3)})
dtc_imp_features.sort_values('importance', ascending=False, inplace=True); dtc_imp_features
# Out:
#                    feature  importance
# 1   wholesale_price_mmnorm       0.955
# 0     selling_price_mmnorm       0.045
# 2            Mileage_mnorm       0.000
# 3           odometer_mnorm       0.000
# 4                name_code       0.000
# 5                body_code       0.000
# 6        transmission_code       0.000
# 7               color_code       0.000
# 8            interior_code       0.000
# 9              seller_code       0.000
# 10          condition_code       0.000

# %%
# Decision Tree : Model Prediction (Training Subset)
dtc_model_predict = dtc_model.predict(cars_inputs_train); dtc_model_predict
# Out:
# array([0, 3, 3, ..., 0, 1, 0])

# %%
# Decision Tree : Prediction (Testing Subset)
dtc_predict = dtc_model.predict(cars_inputs_test); dtc_predict
# Out:
# array([0, 1, 0, ..., 3, 1, 0])

# %%
# Decision Tree : Model Evaluation (Training Subset)
dtc_model_conf_mat = pd.DataFrame(confusion_matrix(cars_output_train, dtc_model_predict)); dtc_model_conf_mat
dtc_model_perf = classification_report(cars_output_train, dtc_model_predict); print(dtc_model_perf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98     30051
#            1       0.98      0.95      0.96     31974
#            2       0.93      0.96      0.95      2700
#            3       0.95      0.95      0.95     15274
#
#     accuracy                           0.97     79999
#    macro avg       0.96      0.96      0.96     79999
# weighted avg       0.97      0.97      0.97     79999

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Set a larger figure size for better clarity
plt.figure(figsize=(10, 10))

# Plot the decision tree
train_subset_dtc_plot = plot_tree(dtc_model, feature_names=cars_inputs_names, class_names=cars_output_labels, rounded=True, filled=True, fontsize=20)

# Show the plot
plt.show()

# %%
# Set up the plot
ax = plt.axes()

# Plot the confusion matrix with annotations in integer format
sns.heatmap(dtc_model_conf_mat, annot=True, fmt='d', cmap='Paired')

# Set labels and title
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Decision Tree : Confusion Matrix')

# Show the plot
plt.show()

# %%
# Cross Validation
from sklearn.model_selection import cross_val_score

# Define your decision tree classifier with desired parameters
dtc_cv = DecisionTreeClassifier(criterion='gini', random_state=45007)

# Perform 5-fold cross-validation
cv_scores = cross_val_score(dtc_cv, cars_inputs, cars_output.values.ravel(), cv=20)
print("Cross-Validation Scores:", cv_scores)
print("Average Cross-Validation Score:", np.mean(cv_scores))
# Out:
# Cross-Validation Scores: [0.9966     0.9958     0.9972     0.9966     0.998      0.998
#  0.998      0.9974     0.998      0.9974     0.9974     0.9984
#  0.9968     0.9972     0.9974     0.996      0.9978     0.998
#  0.9968     0.99559912]
# Average Cross-Validation Score: 0.9972199559911983

# %%
from sklearn.metrics import f1_score

# Compute F1 score
f1 = f1_score(cars_output_test, dtc_predict, average='macro')  # or 'weighted' for weighted F1 score
print("F1 Score:", f1)

# Weighted F1 score
weighted_f1 = f1_score(cars_output_test, dtc_predict, average='weighted')
print("Weighted F1 Score:", weighted_f1)
# Out:
# F1 Score: 0.956960021061735
# Weighted F1 Score: 0.9663270158478655

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, cross_val_score
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import SVC
import numpy as np
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Data preprocessing and splitting
# Assuming you have your data loaded into cars_inputs and cars_output
cars_inputs_train, cars_inputs_test, cars_output_train, cars_output_test = train_test_split(cars_inputs, cars_output, test_size=0.2, random_state=42)

# End time
end_time = time.time()

# Time taken for data preprocessing and splitting
data_preprocessing_time = end_time - start_time

# Memory usage after data preprocessing
data_preprocessing_memory = memory_usage()

# Decision Tree
dt_start_time = time.time()
dt_model = DecisionTreeClassifier(criterion='gini', random_state=45007, max_depth=3)
dt_model.fit(cars_inputs_train, cars_output_train)
dt_training_time = time.time() - dt_start_time
dt_memory_used = memory_usage()
dt_pred = dt_model.predict(cars_inputs_test)
dt_accuracy = accuracy_score(cars_output_test, dt_pred)

# Cross-validation for Decision Tree
dtc_cv_start_time = time.time()
dtc_cv = DecisionTreeClassifier(criterion='gini', random_state=45007)
cv_scores_dtc = cross_val_score(dtc_cv, cars_inputs, cars_output.values.ravel(), cv=20)
dtc_cv_time = time.time() - dtc_cv_start_time
dtc_cv_accuracy = np.mean(cv_scores_dtc)

print("Decision Tree:")
print(f"  - Training Time (s): {dt_training_time}")
print(f"  - Memory Used (MB): {dt_memory_used}")
print(f"  - Single Split Accuracy: {dt_accuracy}")
print(f"  - Cross Validation Accuracy: {dtc_cv_accuracy}")
print()
# Out:
# Decision Tree:
#   - Training Time (s): 0.4926416873931885
#   - Memory Used (MB): 438.84765625
#   - Single Split Accuracy: 0.9671
#   - Cross Validation Accuracy: 0.9972199559911983

# %% [markdown]
# ##**Random Forest**

# %%
## Data Visualization Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from wordcloud import WordCloud
from collections import Counter
from scipy import stats
from sklearn.tree import plot_tree
import graphviz
from IPython.display import display
from collections import Counter

## Machine Learning Models and Evaluation Metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.validation import column_or_1d
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score, precision_recall_fscore_support
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression, Lasso, Ridge
from sklearn.metrics import make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.tree import export_graphviz

# %%
rf_classifier.fit(cars_inputs_train, cars_output_train['cluster'])
# Out:
# RandomForestClassifier(random_state=45011)

# %%
y_train_pred_rf = rf_classifier.predict(cars_inputs_train)
y_test_pred_rf = rf_classifier.predict(cars_inputs_test)

# %%
# Train the Random Forest classifier
rf_classifier.fit(cars_inputs_train, cars_output_train['cluster'])

# Print feature importances
feature_importances = rf_classifier.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': cars_inputs_train.columns, 'Importance': feature_importances})
sorted_feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
print("Feature Importances:")
print(sorted_feature_importance_df)
# Out:
# Feature Importances:
#                    Feature  Importance
# 1   wholesale_price_mmnorm    0.438817
# 0     selling_price_mmnorm    0.436684
# 3           odometer_mnorm    0.085960
# 5                body_code    0.011646
# 4                name_code    0.007784
# 9              seller_code    0.007002
# 2            Mileage_mnorm    0.004484
# 8            interior_code    0.004364
# 7               color_code    0.002300
# 10          condition_code    0.000686
# 6        transmission_code    0.000274

# %%
# For training set
print("Training Set Confusion Matrix:")
print(confusion_matrix(cars_output_train['cluster'], y_train_pred_rf))

print("\nTraining Set Classification Report:")
print(classification_report(cars_output_train['cluster'], y_train_pred_rf))
# Out:
# Training Set Confusion Matrix:
# [[30117     0     0     0]
#  [    0 31844     0     0]
#  [    0     0  2719     0]
#  [    0     0     0 15319]]
#
# Training Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     30117
#            1       1.00      1.00      1.00     31844
#            2       1.00      1.00      1.00      2719
#            3       1.00      1.00      1.00     15319
#
#     accuracy                           1.00     79999
#    macro avg       1.00      1.00      1.00     79999
# weighted avg       1.00      1.00      1.00     79999

# %%
# For testing set
print("\nTesting Set Confusion Matrix:")
print(confusion_matrix(cars_output_test['cluster'], y_test_pred_rf))

print("\nTesting Set Classification Report:")
print(classification_report(cars_output_test['cluster'], y_test_pred_rf))
# Out:
# Testing Set Confusion Matrix:
# [[7434   13    0    0]
#  [  20 8094    0    9]
#  [   0    0  648    8]
#  [   0   15    3 3756]]
#
# Testing Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7447
#            1       1.00      1.00      1.00      8123
#            2       1.00      0.99      0.99       656
#            3       1.00      1.00      1.00      3774
#
#     accuracy                           1.00     20000
#    macro avg       1.00      0.99      1.00     20000
# weighted avg       1.00      1.00      1.00     20000

# %%
# Assuming rf is your trained Random Forest classifier
for i in range(3):
    tree = rf_classifier.estimators_[i]  # Assuming rf_classifier is your trained Random Forest model
    dot_data = export_graphviz(tree,
                               feature_names=cars_inputs_train.columns,
                               filled=True,
                               max_depth=2,
                               impurity=False,
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
# Export and visualize the first three decision trees
for i in range(3):
    tree = rf_classifier.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=cars_inputs_train.columns,
                               filled=True,
                               max_depth=2,
                               impurity=False,
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
# Initialize a dictionary to store tree frequencies and rules
tree_frequency = Counter()
tree_rules = {}

# Loop through the trees and count their frequency while storing rules
for i in range(len(rf_classifier.estimators_)):
    tree = rf_classifier.estimators_[i]
    tree_str = export_text(tree, feature_names=list(cars_inputs_train.columns))
    tree_frequency[tree_str] += 1
    tree_rules[tree_str] = tree

# Get the three most frequent trees
top_trees = tree_frequency.most_common(3)

# Print the rules for the top three trees
for tree_str, frequency in top_trees:
    print(f"Tree Frequency: {frequency}")
    print(tree_str)
    print("\n")
# Out:
# Tree Frequency: 1
# |--- wholesale_price_mmnorm <= 0.05
# |   |--- odometer_mnorm <= 0.08
# |   |   |--- odometer_mnorm <= 0.08
# |   |   |   |--- wholesale_price_mmnorm <= 0.05
# |   |   |   |   |--- wholesale_price_mmnorm <= 0.05
# |   |   |   |   |   |--- selling_price_mmnorm <= 0.06
# |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |--- selling_price_mmnorm >  0.06
# |   |   |   |   |   |   |--- odometer_mnorm <= 0.07
# |   |   |   |   |   |   |   |--- selling_price_mmnorm <= 0.08
# |   |   |   |   |   |   |   |   |--- name_code <= 44.50
# |   |   |   |   |   |   |   |   |   |--- wholesale_price_mmnorm <= 0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |   |   |--- wholesale_price_mmnorm >  0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: 1.0
# |   |   |   |   |   |   |   |   |--- name_code >  44.50
# |   |   |   |   |   |   |   |   |   |--- class: 1.0
# ...

# %%
# Initialize a dictionary to store tree frequencies
tree_frequency = Counter()

# Loop through the trees and count their frequency
for i in range(len(rf_classifier.estimators_)):
    tree = rf_classifier.estimators_[i]
    tree_str = export_graphviz(tree, feature_names=cars_inputs_train.columns,
                               filled=True, max_depth=2, impurity=False, proportion=True)
    tree_frequency[tree_str] += 1

# Get the three most frequent trees
top_trees = tree_frequency.most_common(3)

# Plot the top three trees
for tree_str, frequency in top_trees:
    graph = graphviz.Source(tree_str)
    display(graph)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from wordcloud import WordCloud
from collections import Counter
from scipy import stats
from sklearn.tree import plot_tree, export_graphviz
import graphviz
from IPython.display import display
from collections import Counter
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Initialize Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=45011)

# Train the Random Forest classifier
rf_classifier.fit(cars_inputs_train, cars_output_train['cluster'])

# Predictions
y_train_pred_rf = rf_classifier.predict(cars_inputs_train)
y_test_pred_rf = rf_classifier.predict(cars_inputs_test)

# End time
end_time = time.time()

# Time taken
execution_time = end_time - start_time

# Memory usage
memory_used = memory_usage()

# Accuracy
accuracy_train = accuracy_score(cars_output_train['cluster'], y_train_pred_rf)
accuracy_test = accuracy_score(cars_output_test['cluster'], y_test_pred_rf)

# Print time, memory usage, and accuracy
print("Time taken (seconds):", execution_time)
print("Memory used (MB):", memory_used)
print("Training Set Accuracy:", accuracy_train)
print("Testing Set Accuracy:", accuracy_test)

# Print feature importances
feature_importances = rf_classifier.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': cars_inputs_train.columns, 'Importance': feature_importances})
sorted_feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
print("\nFeature Importances:")
print(sorted_feature_importance_df)

# Print confusion matrix and classification report for training set
print("\nTraining Set Confusion Matrix:")
print(confusion_matrix(cars_output_train['cluster'], y_train_pred_rf))
print("\nTraining Set Classification Report:")
print(classification_report(cars_output_train['cluster'], y_train_pred_rf))

# Print confusion matrix and classification report for testing set
print("\nTesting Set Confusion Matrix:")
print(confusion_matrix(cars_output_test['cluster'], y_test_pred_rf))
print("\nTesting Set Classification Report:")
print(classification_report(cars_output_test['cluster'], y_test_pred_rf))

# Export and visualize the first three decision trees
for i in range(3):
    tree = rf_classifier.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=cars_inputs_train.columns,
                               filled=True,
                               max_depth=2,
                               impurity=False,
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# Initialize a dictionary to store tree frequencies and rules
tree_frequency = Counter()
tree_rules = {}

# Loop through the trees and count their frequency while storing rules
for i in range(len(rf_classifier.estimators_)):
    tree = rf_classifier.estimators_[i]
    tree_str = export_text(tree, feature_names=list(cars_inputs_train.columns))
    tree_frequency[tree_str] += 1
    tree_rules[tree_str] = tree

# Get the three most frequent trees
top_trees = tree_frequency.most_common(3)

# Print the rules for the top three trees
for tree_str, frequency in top_trees:
    print(f"Tree Frequency: {frequency}")
    print(tree_str)
    print("\n")

# Initialize a dictionary to store tree frequencies
tree_frequency = Counter()

# Loop through the trees and count their frequency
for i in range(len(rf_classifier.estimators_)):
    tree = rf_classifier.estimators_[i]
    tree_str = export_graphviz(tree, feature_names=cars_inputs_train.columns,
                               filled=True, max_depth=2, impurity=False, proportion=True)
    tree_frequency[tree_str] += 1

# Get the three most frequent trees
top_trees = tree_frequency.most_common(3)

# Plot the top three trees
for tree_str, frequency in top_trees:
    graph = graphviz.Source(tree_str)
    display(graph)
# Out:
# Time taken (seconds): 20.439834356307983
# Memory used (MB): 481.29296875
# Training Set Accuracy: 1.0
# Testing Set Accuracy: 0.9966
#
# Feature Importances:
#                    Feature  Importance
# 1   wholesale_price_mmnorm    0.438817
# 0     selling_price_mmnorm    0.436684
# 3           odometer_mnorm    0.085960
# 5                body_code    0.011646
# 4                name_code    0.007784
# 9              seller_code    0.007002
# 2            Mileage_mnorm    0.004484
# 8            interior_code    0.004364
# 7               color_code    0.002300
# 10          condition_code    0.000686
# 6        transmission_code    0.000274
#
# Training Set Confusion Matrix:
# [[30117     0     0     0]
#  [    0 31844     0     0]
#  [    0     0  2719     0]
#  [    0     0     0 15319]]
#
# Training Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     30117
# ...

# %%
import pandas as pd
import numpy as np
import time
import psutil
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Data preprocessing and splitting
# Assuming you have your data loaded into cars_inputs and cars_output
cars_inputs_train, cars_inputs_test, cars_output_train, cars_output_test = train_test_split(cars_inputs, cars_output, test_size=0.2, random_state=42)

# Initialize lists to store results
models = []
training_times = []
memory_used = []
single_split_accuracies = []
cross_validation_accuracies = []

# Decision Tree
dt_start_time = time.time()
dt_model = DecisionTreeClassifier(criterion='gini', random_state=45011, max_depth=3)
dt_model.fit(cars_inputs_train, cars_output_train)
dt_training_time = time.time() - dt_start_time
dt_memory_used = memory_usage()
dt_pred = dt_model.predict(cars_inputs_test)
dt_accuracy = accuracy_score(cars_output_test, dt_pred)

# Cross-validation for Decision Tree
dtc_cv_start_time = time.time()
dtc_cv = DecisionTreeClassifier(criterion='gini', random_state=45011)
cv_scores_dtc = cross_val_score(dtc_cv, cars_inputs, cars_output.values.ravel(), cv=20)
dtc_cv_time = time.time() - dtc_cv_start_time
dtc_cv_accuracy = np.mean(cv_scores_dtc)

# Append Decision Tree results to lists
models.append('Decision Tree')
training_times.append(dt_training_time)
memory_used.append(dt_memory_used)
single_split_accuracies.append(dt_accuracy)
cross_validation_accuracies.append(dtc_cv_accuracy)

# Random Forest
rf_start_time = time.time()
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=45011)
rf_classifier.fit(cars_inputs_train, cars_output_train['cluster'])
rf_training_time = time.time() - rf_start_time
rf_memory_used = memory_usage()
y_train_pred_rf = rf_classifier.predict(cars_inputs_train)
y_test_pred_rf = rf_classifier.predict(cars_inputs_test)
rf_accuracy_train = accuracy_score(cars_output_train['cluster'], y_train_pred_rf)
rf_accuracy_test = accuracy_score(cars_output_test['cluster'], y_test_pred_rf)

# Append Random Forest results to lists
models.append('Random Forest')
training_times.append(rf_training_time)
memory_used.append(rf_memory_used)
single_split_accuracies.append(rf_accuracy_test)  # Using test accuracy as we already calculated it
cross_validation_accuracies.append(np.nan)  # Cross-validation accuracy not calculated here

# Create DataFrame
results_df = pd.DataFrame({
    'Model': models,
    'Training Time (s)': training_times,
    'Memory Used (MB)': memory_used,
    'Single Split Accuracy': single_split_accuracies,
    'Cross Validation Accuracy': cross_validation_accuracies
})

# Print DataFrame
print(results_df)
# Out:
#            Model  Training Time (s)  Memory Used (MB)  Single Split Accuracy  \
# 0  Decision Tree           0.549888        481.292969                 0.9671
# 1  Random Forest          14.168092        482.582031                 0.9966
#
#    Cross Validation Accuracy
# 0                    0.99717
# 1                        NaN
